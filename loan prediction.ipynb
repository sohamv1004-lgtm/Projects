# %%
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
import numpy as mp
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\Soham\Downloads\loan acceptance.csv")
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
df.shape
# Out:
# (480, 13)

# %%
df.describe()
# Out:
#            Gender     Married   Education  Self_Employed  ApplicantIncome  \
# count  480.000000  480.000000  480.000000     480.000000       480.000000
# mean     0.820833    0.647917    0.797917       0.137500      5364.231250
# std      0.383892    0.478118    0.401973       0.344734      5668.251251
# min      0.000000    0.000000    0.000000       0.000000       150.000000
# 25%      1.000000    0.000000    1.000000       0.000000      2898.750000
# 50%      1.000000    1.000000    1.000000       0.000000      3859.000000
# 75%      1.000000    1.000000    1.000000       0.000000      5852.500000
# max      1.000000    1.000000    1.000000       1.000000     81000.000000
#
#        CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# count         480.000000  480.000000        480.000000      480.000000
# mean         1581.093583  144.735417        342.050000        0.854167
# std          2617.692267   80.508164         65.212401        0.353307
# ...

# %%
df.isnull().sum() #checks missing rows
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
df=df.dropna()
df.shape
# Out:
# (480, 13)

# %%
df.replace({'Loan_Status':{'N':0,'Y':1}},inplace=True)
df
# Out:
#       Loan_ID  Gender  Married Dependents  Education  Self_Employed  \
# 1    LP001003       1        1          1          1              0
# 2    LP001005       1        1          0          1              1
# 3    LP001006       1        1          0          0              0
# 4    LP001008       1        0          0          1              0
# 5    LP001011       1        1          2          1              1
# ..        ...     ...      ...        ...        ...            ...
# 609  LP002978       0        0          0          1              0
# 610  LP002979       1        1          4          1              0
# 611  LP002983       1        1          1          1              0
# 612  LP002984       1        1          2          1              0
# 613  LP002990       0        0          0          1              1
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 1               4583             1508.0       128.0             360.0
# ...

# %%
df=df.replace(to_replace='3+',value='4')
df
# Out:
#       Loan_ID  Gender  Married Dependents  Education  Self_Employed  \
# 1    LP001003       1        1          1          1              0
# 2    LP001005       1        1          0          1              1
# 3    LP001006       1        1          0          0              0
# 4    LP001008       1        0          0          1              0
# 5    LP001011       1        1          2          1              1
# ..        ...     ...      ...        ...        ...            ...
# 609  LP002978       0        0          0          1              0
# 610  LP002979       1        1          4          1              0
# 611  LP002983       1        1          1          1              0
# 612  LP002984       1        1          2          1              0
# 613  LP002990       0        0          0          1              1
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 1               4583             1508.0       128.0             360.0
# ...

# %%
df['Dependents'].value_counts()
# Out:
# Dependents
# 0    274
# 2     85
# 1     80
# 4     41
# Name: count, dtype: int64

# %%
sns.countplot(x='Education',hue='Loan_Status',data=df)
# Out:
# <Axes: xlabel='Education', ylabel='count'>

# %%
sns.countplot(x='Married',hue='Loan_Status',data=df)
# Out:
# <Axes: xlabel='Married', ylabel='count'>

# %%
sns.countplot(x='Self_Employed',hue='Loan_Status',data=df)
# Out:
# <Axes: xlabel='Self_Employed', ylabel='count'>

# %%
sns.countplot(x='Gender',hue='Loan_Status',data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
df.replace({'Education':{'Not Graduate':0,'Graduate':1}},inplace=True)
df.replace({'Married':{'No':0,'Yes':1}},inplace=True)
df.replace({'Self_Employed':{'No':0,'Yes':1}},inplace=True)
df.replace({'Property_Area':{'Rural':0,'Semiurban':1,'Urban':2}},inplace=True)
df.replace({'Gender':{'Female':0,'Male':1}},inplace=True)
# Out:
# C:\Users\Soham\AppData\Local\Temp\ipykernel_25288\410593311.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace({'Education':{'Not Graduate':0,'Graduate':1}},inplace=True)
# C:\Users\Soham\AppData\Local\Temp\ipykernel_25288\410593311.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace({'Married':{'No':0,'Yes':1}},inplace=True)
# ...

# %%
df.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
input=df.drop(['Loan_ID','Loan_Status'],axis='columns')
target=df['Loan_Status']

# %%
X_train,X_test,Y_train,Y_test=train_test_split(input,target,test_size=0.2,stratify=target,random_state=42)

# %%
from sklearn import svm

# %%
model=svm.SVC(kernel='linear')

# %%
model.fit(X_train,Y_train)
# Out:
# SVC(kernel='linear')

# %%
df
# Out:
#       Loan_ID  Gender  Married Dependents  Education  Self_Employed  \
# 1    LP001003       1        1          1          1              0
# 2    LP001005       1        1          0          1              1
# 3    LP001006       1        1          0          0              0
# 4    LP001008       1        0          0          1              0
# 5    LP001011       1        1          2          1              1
# ..        ...     ...      ...        ...        ...            ...
# 609  LP002978       0        0          0          1              0
# 610  LP002979       1        1          4          1              0
# 611  LP002983       1        1          1          1              0
# 612  LP002984       1        1          2          1              0
# 613  LP002990       0        0          0          1              1
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 1               4583             1508.0       128.0             360.0
# ...

# %%
X_train_prediction=model.predict(X_train)
training_data_accuracy=accuracy_score(X_train_prediction,Y_train)

# %%
training_data_accuracy
# Out:
# 0.8046875

# %%
X_test_prediction=model.predict(X_test)
test_data_accuracy=accuracy_score(X_test_prediction,Y_test)

# %%
# Out:
# LinearRegression()

# %%
test_data_accuracy
# Out:
# 0.8333333333333334
